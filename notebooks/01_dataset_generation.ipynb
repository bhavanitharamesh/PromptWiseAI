# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from utils.dataset_generator import generate_dataset

# %%
df = generate_dataset(2500)
print("success")
# Out:
# success

# %%
df.head()
# Out:
#   Prompt_ID                   AI_Role                           Task  \
# 0   PW00001          Business Analyst  Business Requirement Analysis
# 1   PW00002  Cybersecurity Specialist            Penetration Testing
# 2   PW00003  Cybersecurity Specialist              Incident Response
# 3   PW00004           DevOps Engineer                     Monitoring
# 4   PW00005        Software Architect                Design Patterns
#
#                          Context                 Constraint Output_Format  \
# 0  General Professional Scenario     Avoid technical jargon          JSON
# 1  General Professional Scenario  Follow industry standards           CSV
# 2  General Professional Scenario          Return valid JSON   Python Code
# 3  General Professional Scenario                Use PyTorch           CSV
# 4  General Professional Scenario  Use tables for comparison   Python Code
#
#                     Goal Recommended_AI  \
# 0        Build a Project        ChatGPT
# ...

# %%
df.shape
# Out:
# (2500, 10)

# %%
df.to_csv(r"C:\Users\HP\Desktop\ML\PromptWiseAI\datasets\promptwise_dataset.csv", index=False)

# %%
df["Recommended_AI"].value_counts()
# Out:
# Recommended_AI
# ChatGPT       1965
# Perplexity     212
# Gamma          161
# Claude         142
# NotebookLM      20
# Name: count, dtype: int64
